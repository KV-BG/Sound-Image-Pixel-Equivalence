# %%
# prompt: write a program that accepts 256 different sets of RGB values and assigns the color generated to box and arrange the
#boxes in a 16x16 grid in the same order as that of the rgb value order starting from top- left first moving from left to right
#within a row then moving to the next row. accept rgb values as actual values and not between 0 to 1. don't use anything that requires
#values to be converted to 0-1 scale

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

def create_color_grid(rgb_values):
  """
  Creates a 16x16 grid of colored boxes based on RGB values.

  Args:
    rgb_values: A list of 256 RGB tuples, each tuple representing (R, G, B) values (0-255).

  Returns:
    A matplotlib figure object displaying the color grid.
  """


  if len(rgb_values) != 256:
      raise ValueError("Exactly 256 RGB values are required.")

  # Create a figure and axes
  fig, ax = plt.subplots(figsize=(8, 8))  # Adjust figure size if needed

  # Set axis limits and remove ticks and labels
  ax.set_xlim(0, 16)
  ax.set_ylim(0, 16)
  ax.set_xticks([])
  ax.set_yticks([])


  # Iterate through RGB values and create boxes
  for i in range(16):
      for j in range(16):
          index = i * 16 + j
          color = rgb_values[index]  # Assuming rgb_values contains 256 entries

          # Create a rectangle patch with the specified color
          rect = patches.Rectangle((j, 15-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))

          # Add the rectangle patch to the axes
          ax.add_patch(rect)

  # Display the grid
  plt.show()

  return fig


# Example usage: Generate 256 random RGB values

# %%
# prompt: write a code that does the following
# 1. Accepts a audio file
# 2. Divides the audio into 256 equally sized segements
# 3. Calculates the average amplitude of each segement [let that average amplitude be x]
# 4. Generates a tuple of 3 numbers (x, x/2, x/4) for each segment
# 5. Goes through all the generated tuples and its numbers and normalizes all the values so that all the values fall into the range of 0-255
# 6. rounds off the values to the nearest integer by still being within the range of 0-255

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import librosa

def create_color_grid(rgb_values):
  """
  Creates a 16x16 grid of colored boxes based on RGB values.

  Args:
    rgb_values: A list of 256 RGB tuples, each tuple representing (R, G, B) values (0-255).

  Returns:
    A matplotlib figure object displaying the color grid.
  """


  if len(rgb_values) != 1024:
      raise ValueError("Exactly 256 RGB values are required.")

  # Create a figure and axes
  fig, ax = plt.subplots(figsize=(8, 8))  # Adjust figure size if needed

  # Set axis limits and remove ticks and labels
  ax.set_xlim(0, 32)
  ax.set_ylim(0, 32)
  ax.set_xticks([])
  ax.set_yticks([])


  # Iterate through RGB values and create boxes
  for i in range(32):
      for j in range(32):
          index = i * 32 + j
          color = rgb_values[index]  # Assuming rgb_values contains 256 entries

          # Create a rectangle patch with the specified color
          rect = patches.Rectangle((j, 31-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))

          # Add the rectangle patch to the axes
          ax.add_patch(rect)

  # Display the grid
  plt.show()

  return fig

def process_audio(file_path):
    # 1. Load audio file
    try:
        y, sr = librosa.load(file_path)
    except FileNotFoundError:
        print(f"Error: Audio file not found at {file_path}")
        return None

    # 2. Divide into segments
    segment_length = len(y) // 1024
    segments = [y[i * segment_length:(i + 1) * segment_length] for i in range(1024)]

    # 3 & 4. Calculate average amplitude and generate tuples
    tuples = []
    for segment in segments:
        avg_amplitude = np.mean(np.abs(segment))
        tuples.append((avg_amplitude, avg_amplitude, avg_amplitude))

    # 5 & 6. Normalize and round
    all_values = [val for tup in tuples for val in tup]
    min_val = min(all_values)
    max_val = max(all_values)

    normalized_tuples = []
    for tup in tuples:
        normalized_tup = []
        for val in tup:
            normalized_val = int(round(((val - min_val) / (max_val - min_val)) * 255))
            normalized_val = min(255, max(0, normalized_val)) # Ensure within 0-255
            normalized_tup.append(normalized_val)
        normalized_tuples.append(normalized_tup)

    rgb_values = normalized_tuples
    create_color_grid(rgb_values)
    return rgb_values


# Example usage (replace with your audio file path)
file_path1 = "rock.00094.wav"
file_path2 = "rock.00095.wav"

rgb_values1 = process_audio(file_path1)
create_color_grid(rgb_values1)

rgb_values2 = process_audio(file_path2)
create_color_grid(rgb_values2)

# %%
# prompt: write a code that generates these grids for all the audio files uploaded in the colab folder

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import librosa
import os

def create_color_grid(rgb_values):
    """
    Creates a 32x32 grid of colored boxes based on RGB values.
    """
    if len(rgb_values) != 1024:
        raise ValueError("Exactly 1024 RGB values are required.")

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 32)
    ax.set_ylim(0, 32)
    ax.set_xticks([])
    ax.set_yticks([])

    for i in range(32):
        for j in range(32):
            index = i * 32 + j
            color = rgb_values[index]
            rect = patches.Rectangle((j, 31-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))
            ax.add_patch(rect)

    plt.show()
    return fig

def process_audio(file_path):
    try:
        y, sr = librosa.load(file_path)
    except FileNotFoundError:
        print(f"Error: Audio file not found at {file_path}")
        return None

    segment_length = len(y) // 1024
    segments = [y[i * segment_length:(i + 1) * segment_length] for i in range(1024)]

    tuples = []
    for segment in segments:
        avg_amplitude = np.mean(np.abs(segment))
        tuples.append((avg_amplitude, avg_amplitude, avg_amplitude))

    all_values = [val for tup in tuples for val in tup]
    min_val = min(all_values)
    max_val = max(all_values)

    normalized_tuples = []
    for tup in tuples:
        normalized_tup = []
        for val in tup:
            normalized_val = int(round(((val - min_val) / (max_val - min_val)) * 255))
            normalized_val = min(255, max(0, normalized_val))
            normalized_tup.append(normalized_val)
        normalized_tuples.append(normalized_tup)

    rgb_values = normalized_tuples
    create_color_grid(rgb_values)
    return rgb_values

# Iterate through all audio files in the current directory
for filename in os.listdir():
    if filename.endswith(('.wav', '.mp3', '.ogg')): # Add more audio extensions if needed
        file_path = os.path.join(os.getcwd(), filename)
        print(f"Processing {filename}")
        rgb_values = process_audio(file_path)
        if rgb_values:
            print(f"Finished processing {filename}")
        else:
            print(f"Skipping {filename} due to error")
# Out:
# Processing rock.00028.wav
# Finished processing rock.00028.wav
# Processing rock.00024.wav
# Finished processing rock.00024.wav
# Processing rock.00030.wav
# Finished processing rock.00030.wav
# Processing rock.00081.wav
# Finished processing rock.00081.wav
# Processing rock.00001.wav
# Finished processing rock.00001.wav
# Processing rock.00094.wav
# Finished processing rock.00094.wav
# Processing rock.00033.wav
# Finished processing rock.00033.wav
# Processing rock.00062.wav
# Finished processing rock.00062.wav
# Processing rock.00068.wav
# Finished processing rock.00068.wav
# Processing rock.00061.wav
# Finished processing rock.00061.wav
# Processing rock.00064.wav
# Finished processing rock.00064.wav
# Processing rock.00023.wav
# Finished processing rock.00023.wav
# Processing rock.00098.wav
# Finished processing rock.00098.wav
# Processing rock.00013.wav
# Finished processing rock.00013.wav
# Processing rock.00006.wav
# Finished processing rock.00006.wav
# Processing rock.00080.wav
# Finished processing rock.00080.wav
# Processing rock.00002.wav
# Finished processing rock.00002.wav
# Processing rock.00014.wav
# Finished processing rock.00014.wav
# Processing rock.00097.wav
# Finished processing rock.00097.wav
# Processing rock.00037.wav
# Finished processing rock.00037.wav
# Processing rock.00096.wav
# Finished processing rock.00096.wav
# Processing rock.00035.wav
# Finished processing rock.00035.wav
# Processing rock.00012.wav
# Finished processing rock.00012.wav
# Processing rock.00054.wav
# Finished processing rock.00054.wav
# Processing rock.00055.wav
# Finished processing rock.00055.wav
# Processing rock.00077.wav
# Finished processing rock.00077.wav
# Processing rock.00076.wav
# Finished processing rock.00076.wav
# Processing rock.00003.wav
# Finished processing rock.00003.wav
# Processing rock.00056.wav
# Finished processing rock.00056.wav
# Processing rock.00031.wav
# Finished processing rock.00031.wav
# Processing rock.00025.wav
# Finished processing rock.00025.wav
# Processing rock.00029.wav
# Finished processing rock.00029.wav
# Processing rock.00099.wav
# Finished processing rock.00099.wav
# Processing rock.00057.wav
# Finished processing rock.00057.wav
# Processing rock.00004.wav
# Finished processing rock.00004.wav
# Processing rock.00089.wav
# Finished processing rock.00089.wav
# Processing rock.00065.wav
# Finished processing rock.00065.wav
# Processing rock.00066.wav
# Finished processing rock.00066.wav
# Processing rock.00075.wav
# Finished processing rock.00075.wav
# Processing rock.00005.wav
# Finished processing rock.00005.wav
# Processing rock.00073.wav
# Finished processing rock.00073.wav
# Processing rock.00026.wav
# Finished processing rock.00026.wav
# Processing rock.00085.wav
# Finished processing rock.00085.wav
# Processing rock.00078.wav
# Finished processing rock.00078.wav
# Processing rock.00019.wav
# Finished processing rock.00019.wav
# Processing rock.00082.wav
# Finished processing rock.00082.wav
# Processing rock.00022.wav
# Finished processing rock.00022.wav
# Processing rock.00090.wav
# Finished processing rock.00090.wav
# Processing rock.00009.wav
# Finished processing rock.00009.wav
# Processing rock.00067.wav
# Finished processing rock.00067.wav
# Processing rock.00086.wav
# Finished processing rock.00086.wav
# Processing rock.00000.wav
# Finished processing rock.00000.wav
# Processing rock.00079.wav
# Finished processing rock.00079.wav
# Processing rock.00087.wav
# Finished processing rock.00087.wav
# Processing rock.00018.wav
# Finished processing rock.00018.wav
# Processing rock.00059.wav
# Finished processing rock.00059.wav
# Processing rock.00020.wav
# Finished processing rock.00020.wav
# Processing rock.00095.wav
# Finished processing rock.00095.wav
# Processing rock.00010.wav
# Finished processing rock.00010.wav
# Processing rock.00092.wav
# Finished processing rock.00092.wav
# Processing rock.00021.wav
# Finished processing rock.00021.wav
# Processing rock.00093.wav
# Finished processing rock.00093.wav
# Processing rock.00074.wav
# Finished processing rock.00074.wav
# Processing rock.00063.wav
# Finished processing rock.00063.wav
# Processing rock.00036.wav
# Finished processing rock.00036.wav
# Processing rock.00027.wav
# Finished processing rock.00027.wav
# Processing rock.00007.wav
# Finished processing rock.00007.wav
# Processing rock.00034.wav
# Finished processing rock.00034.wav
# Processing rock.00071.wav
# Finished processing rock.00071.wav
# Processing rock.00088.wav
# Finished processing rock.00088.wav
# Processing rock.00008.wav
# Finished processing rock.00008.wav
# Processing rock.00084.wav
# Finished processing rock.00084.wav
# Processing rock.00083.wav
# Finished processing rock.00083.wav
# Processing rock.00070.wav
# Finished processing rock.00070.wav
# Processing rock.00058.wav
# Finished processing rock.00058.wav
# Processing rock.00032.wav
# Finished processing rock.00032.wav
# Processing rock.00091.wav
# Finished processing rock.00091.wav
# Processing rock.00060.wav
# Finished processing rock.00060.wav
# Processing rock.00011.wav
# Finished processing rock.00011.wav

# %%
# prompt: write a code that generates these grids for all the audio files uploaded in the 'blues' folder

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import librosa
import os

def create_color_grid(rgb_values):
    """
    Creates a 32x32 grid of colored boxes based on RGB values.
    """
    if len(rgb_values) != 1024:
        raise ValueError("Exactly 1024 RGB values are required.")

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 32)
    ax.set_ylim(0, 32)
    ax.set_xticks([])
    ax.set_yticks([])

    for i in range(32):
        for j in range(32):
            index = i * 32 + j
            color = rgb_values[index]
            rect = patches.Rectangle((j, 31-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))
            ax.add_patch(rect)

    plt.show()
    return fig

def process_audio(file_path):
    try:
        y, sr = librosa.load(file_path)
    except FileNotFoundError:
        print(f"Error: Audio file not found at {file_path}")
        return None

    segment_length = len(y) // 1024
    segments = [y[i * segment_length:(i + 1) * segment_length] for i in range(1024)]

    tuples = []
    for segment in segments:
        avg_amplitude = np.mean(np.abs(segment))
        tuples.append((avg_amplitude, avg_amplitude, avg_amplitude))

    all_values = [val for tup in tuples for val in tup]
    min_val = min(all_values)
    max_val = max(all_values)

    normalized_tuples = []
    for tup in tuples:
        normalized_tup = []
        for val in tup:
            normalized_val = int(round(((val - min_val) / (max_val - min_val)) * 255))
            normalized_val = min(255, max(0, normalized_val))
            normalized_tup.append(normalized_val)
        normalized_tuples.append(normalized_tup)

    rgb_values = normalized_tuples
    create_color_grid(rgb_values)
    return rgb_values

# Assuming 'blues' folder is in the current working directory
blues_folder = "blues"  # Replace with the actual path to your 'blues' folder if different

if not os.path.exists(blues_folder):
    print(f"Error: '{blues_folder}' folder not found.")
else:
    for filename in os.listdir(blues_folder):
        if filename.endswith(('.wav', '.mp3', '.ogg')):
            file_path = os.path.join(blues_folder, filename)
            print(f"Processing {filename}")
            rgb_values = process_audio(file_path)
            if rgb_values:
                print(f"Finished processing {filename}")
            else:
                print(f"Skipping {filename} due to error")
# Out:
# Processing blues.00003.wav
# Finished processing blues.00003.wav
# Processing blues.00029.wav
# Finished processing blues.00029.wav
# Processing blues.00082.wav
# Finished processing blues.00082.wav
# Processing blues.00010.wav
# Finished processing blues.00010.wav
# Processing blues.00085.wav
# Finished processing blues.00085.wav
# Processing blues.00007.wav
# Finished processing blues.00007.wav
# Processing blues.00032.wav
# Finished processing blues.00032.wav
# Processing blues.00050.wav
# Finished processing blues.00050.wav
# Processing blues.00077.wav
# Finished processing blues.00077.wav
# Processing blues.00017.wav
# Finished processing blues.00017.wav
# Processing blues.00068.wav
# Finished processing blues.00068.wav
# Processing blues.00070.wav
# Finished processing blues.00070.wav
# Processing blues.00056.wav
# Finished processing blues.00056.wav
# Processing blues.00072.wav
# Finished processing blues.00072.wav
# Processing blues.00088.wav
# Finished processing blues.00088.wav
# Processing blues.00049.wav
# Finished processing blues.00049.wav
# Processing blues.00096.wav
# Finished processing blues.00096.wav
# Processing blues.00030.wav
# Finished processing blues.00030.wav
# Processing blues.00052.wav
# Finished processing blues.00052.wav
# Processing blues.00043.wav
# Finished processing blues.00053.wav
# Processing blues.00034.wav
# Finished processing blues.00034.wav
# Processing blues.00054.wav
# Finished processing blues.00054.wav
# Processing blues.00020.wav
# Finished processing blues.00020.wav
# Processing blues.00047.wav
# Finished processing blues.00047.wav
# Processing blues.00067.wav
# Finished processing blues.00067.wav
# Processing blues.00061.wav
# Finished processing blues.00061.wav
# Processing blues.00025.wav
# Finished processing blues.00025.wav
# Processing blues.00000.wav
# Finished processing blues.00000.wav
# Processing blues.00028.wav
# Finished processing blues.00028.wav
# Processing blues.00002.wav
# Finished processing blues.00002.wav
# Processing blues.00069.wav
# Finished processing blues.00069.wav
# Processing blues.00080.wav
# Finished processing blues.00080.wav
# Processing blues.00039.wav
# Finished processing blues.00039.wav
# Processing blues.00038.wav
# Finished processing blues.00038.wav
# Processing blues.00073.wav
# Finished processing blues.00073.wav
# Processing blues.00016.wav
# Finished processing blues.00016.wav
# Processing blues.00091.wav
# Finished processing blues.00091.wav
# Processing blues.00094.wav
# Finished processing blues.00094.wav
# Processing blues.00026.wav
# Finished processing blues.00026.wav
# Processing blues.00014.wav
# Finished processing blues.00014.wav
# Processing blues.00004.wav
# Finished processing blues.00004.wav
# Processing blues.00046.wav
# Finished processing blues.00046.wav
# Processing blues.00090.wav
# Finished processing blues.00090.wav

# %%
# prompt: write a code that generates these grids for all the audio files uploaded in the 'classical' folder

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import librosa
import os

def create_color_grid(rgb_values):
    """
    Creates a 32x32 grid of colored boxes based on RGB values.
    """
    if len(rgb_values) != 1024:
        raise ValueError("Exactly 1024 RGB values are required.")

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 32)
    ax.set_ylim(0, 32)
    ax.set_xticks([])
    ax.set_yticks([])

    for i in range(32):
        for j in range(32):
            index = i * 32 + j
            color = rgb_values[index]
            rect = patches.Rectangle((j, 31-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))
            ax.add_patch(rect)

    plt.show()
    return fig

def process_audio(file_path):
    try:
        y, sr = librosa.load(file_path)
    except FileNotFoundError:
        print(f"Error: Audio file not found at {file_path}")
        return None

    segment_length = len(y) // 1024
    segments = [y[i * segment_length:(i + 1) * segment_length] for i in range(1024)]

    tuples = []
    for segment in segments:
        avg_amplitude = np.mean(np.abs(segment))
        tuples.append((avg_amplitude, avg_amplitude, avg_amplitude))

    all_values = [val for tup in tuples for val in tup]
    min_val = min(all_values)
    max_val = max(all_values)

    normalized_tuples = []
    for tup in tuples:
        normalized_tup = []
        for val in tup:
            normalized_val = int(round(((val - min_val) / (max_val - min_val)) * 255))
            normalized_val = min(255, max(0, normalized_val))
            normalized_tup.append(normalized_val)
        normalized_tuples.append(normalized_tup)

    rgb_values = normalized_tuples
    create_color_grid(rgb_values)
    return rgb_values

# Assuming 'classical' folder is in the current working directory
classical_folder = "classical"  # Replace with the actual path if different

if not os.path.exists(classical_folder):
    print(f"Error: '{classical_folder}' folder not found.")
else:
    for filename in os.listdir(classical_folder):
        if filename.endswith(('.wav', '.mp3', '.ogg')):
            file_path = os.path.join(classical_folder, filename)
            print(f"Processing {filename}")
            rgb_values = process_audio(file_path)
            if rgb_values:
                print(f"Finished processing {filename}")
            else:
                print(f"Skipping {filename} due to error")
# Out:
# Processing classical.00008.wav
# Finished processing classical.00082.wav
# Processing classical.00005.wav
# Finished processing classical.00005.wav
# Processing classical.00045.wav
# Finished processing classical.00045.wav
# Processing classical.00046.wav
# Finished processing classical.00046.wav
# Processing classical.00043.wav
# Finished processing classical.00043.wav
# Processing classical.00061.wav
# Finished processing classical.00061.wav
# Processing classical.00062.wav
# Finished processing classical.00062.wav
# Processing classical.00063.wav
# Finished processing classical.00063.wav
# Processing classical.00040.wav
# Finished processing classical.00040.wav
# Processing classical.00039.wav
# Finished processing classical.00039.wav
# Processing classical.00041.wav
# Finished processing classical.00041.wav
# Processing classical.00078.wav
# Finished processing classical.00078.wav
# Processing classical.00065.wav
# Finished processing classical.00065.wav
# Processing classical.00064.wav
# Finished processing classical.00064.wav
# Processing classical.00007.wav
# Finished processing classical.00007.wav
# Processing classical.00085.wav
# Finished processing classical.00085.wav
# Processing classical.00068.wav
# Finished processing classical.00068.wav
# Processing classical.00009.wav
# Finished processing classical.00009.wav
# Processing classical.00076.wav
# Finished processing classical.00076.wav
# Processing classical.00042.wav
# Finished processing classical.00042.wav
# Processing classical.00086.wav
# Finished processing classical.00086.wav
# Processing classical.00089.wav
# Finished processing classical.00089.wav
# Processing classical.00091.wav
# Finished processing classical.00091.wav
# Processing classical.00032.wav
# Finished processing classical.00032.wav
# Processing classical.00000.wav
# Finished processing classical.00000.wav
# Processing classical.00031.wav
# Finished processing classical.00031.wav
# Processing classical.00047.wav
# Finished processing classical.00047.wav
# Processing classical.00038.wav
# Finished processing classical.00038.wav
# Processing classical.00036.wav
# Finished processing classical.00036.wav
# Processing classical.00050.wav
# Finished processing classical.00050.wav
# Processing classical.00098.wav
# Finished processing classical.00098.wav
# Processing classical.00020.wav
# Finished processing classical.00020.wav
# Processing classical.00028.wav
# Finished processing classical.00028.wav
# Processing classical.00077.wav
# Finished processing classical.00077.wav
# Processing classical.00084.wav
# Finished processing classical.00084.wav
# Processing classical.00096.wav
# Finished processing classical.00096.wav
# Processing classical.00092.wav
# Finished processing classical.00092.wav
# Processing classical.00072.wav
# Finished processing classical.00072.wav
# Processing classical.00004.wav
# Finished processing classical.00004.wav
# Processing classical.00070.wav
# Finished processing classical.00070.wav
# Processing classical.00018.wav
# Finished processing classical.00018.wav
# Processing classical.00093.wav
# Finished processing classical.00093.wav
# Processing classical.00027.wav
# Finished processing classical.00027.wav

# %%
# prompt: export these grids in the form of images in a single file showing the correspondance of each image with its audio

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import librosa
import os

def create_color_grid(rgb_values, filename):
    """
    Creates a 32x32 grid of colored boxes based on RGB values and saves it as an image.
    """
    if len(rgb_values) != 1024:
        raise ValueError("Exactly 1024 RGB values are required.")

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 32)
    ax.set_ylim(0, 32)
    ax.set_xticks([])
    ax.set_yticks([])

    for i in range(32):
        for j in range(32):
            index = i * 32 + j
            color = rgb_values[index]
            rect = patches.Rectangle((j, 31-i), 1, 1, linewidth=0, facecolor=tuple(np.array(color)/255))
            ax.add_patch(rect)

    # Save the figure as an image
    image_filename = filename.split('.')[0] + ".png"  # Create image filename based on audio filename
    fig.savefig(image_filename)
    plt.close(fig)  # Close the figure to free up memory


def process_audio(file_path):
    try:
        y, sr = librosa.load(file_path)
    except FileNotFoundError:
        print(f"Error: Audio file not found at {file_path}")
        return None

    segment_length = len(y) // 1024
    segments = [y[i * segment_length:(i + 1) * segment_length] for i in range(1024)]

    tuples = []
    for segment in segments:
        avg_amplitude = np.mean(np.abs(segment))
        tuples.append((avg_amplitude, avg_amplitude, avg_amplitude))

    all_values = [val for tup in tuples for val in tup]
    min_val = min(all_values)
    max_val = max(all_values)

    normalized_tuples = []
    for tup in tuples:
        normalized_tup = []
        for val in tup:
            normalized_val = int(round(((val - min_val) / (max_val - min_val)) * 255))
            normalized_val = min(255, max(0, normalized_val))
            normalized_tup.append(normalized_val)
        normalized_tuples.append(normalized_tup)

    rgb_values = normalized_tuples
    return rgb_values


# Iterate through all audio files in the current directory
for filename in os.listdir():
    if filename.endswith(('.wav', '.mp3', '.ogg')):
        file_path = os.path.join(os.getcwd(), filename)
        print(f"Processing {filename}")
        rgb_values = process_audio(file_path)
        if rgb_values:
            create_color_grid(rgb_values, filename) # Pass filename to create_color_grid
            print(f"Finished processing {filename} and saved image.")
        else:
            print(f"Skipping {filename} due to error")
# Out:
# Processing rock.00028.wav
# Finished processing rock.00028.wav and saved image.
# Processing rock.00024.wav
# Finished processing rock.00024.wav and saved image.
# Processing rock.00030.wav
# Finished processing rock.00030.wav and saved image.
# Processing rock.00081.wav
# Finished processing rock.00081.wav and saved image.
# Processing rock.00001.wav
# Finished processing rock.00001.wav and saved image.
# Processing rock.00094.wav
# Finished processing rock.00094.wav and saved image.
# Processing rock.00033.wav
# Finished processing rock.00033.wav and saved image.
# Processing rock.00062.wav
# Finished processing rock.00062.wav and saved image.
# Processing rock.00068.wav
# Finished processing rock.00068.wav and saved image.
# Processing rock.00061.wav
# Finished processing rock.00061.wav and saved image.
# Processing rock.00064.wav
# Finished processing rock.00064.wav and saved image.
# Processing rock.00023.wav
# Finished processing rock.00023.wav and saved image.
# Processing rock.00098.wav
# Finished processing rock.00098.wav and saved image.
# Processing rock.00013.wav
# Finished processing rock.00013.wav and saved image.
# Processing rock.00006.wav
# Finished processing rock.00006.wav and saved image.
# Processing rock.00080.wav
# Finished processing rock.00080.wav and saved image.
# Processing rock.00002.wav
# Finished processing rock.00002.wav and saved image.
# Processing rock.00014.wav
# Finished processing rock.00014.wav and saved image.
# Processing rock.00097.wav
# Finished processing rock.00097.wav and saved image.
# Processing rock.00037.wav
# Finished processing rock.00037.wav and saved image.
# Processing rock.00096.wav
# Finished processing rock.00096.wav and saved image.
# Processing rock.00035.wav
# Finished processing rock.00035.wav and saved image.
# Processing rock.00012.wav
# Finished processing rock.00012.wav and saved image.
# Processing rock.00054.wav
# Finished processing rock.00054.wav and saved image.
# Processing rock.00055.wav
# Finished processing rock.00055.wav and saved image.
# Processing rock.00077.wav
# Finished processing rock.00077.wav and saved image.
# Processing rock.00076.wav
# Finished processing rock.00076.wav and saved image.
# Processing rock.00003.wav
# Finished processing rock.00003.wav and saved image.
# Processing rock.00056.wav
# Finished processing rock.00056.wav and saved image.
# Processing rock.00031.wav
# Finished processing rock.00031.wav and saved image.
# Processing rock.00025.wav
# Finished processing rock.00025.wav and saved image.
# Processing rock.00029.wav
# Finished processing rock.00029.wav and saved image.
# Processing rock.00099.wav
# Finished processing rock.00099.wav and saved image.
# Processing rock.00057.wav
# Finished processing rock.00057.wav and saved image.
# Processing rock.00004.wav
# Finished processing rock.00004.wav and saved image.
# Processing rock.00089.wav
# Finished processing rock.00089.wav and saved image.
# Processing rock.00065.wav
# Finished processing rock.00065.wav and saved image.
# Processing rock.00066.wav
# Finished processing rock.00066.wav and saved image.
# Processing rock.00075.wav
# Finished processing rock.00075.wav and saved image.
# Processing rock.00005.wav
# Finished processing rock.00005.wav and saved image.
# Processing rock.00073.wav
# Finished processing rock.00073.wav and saved image.
# Processing rock.00026.wav
# Finished processing rock.00026.wav and saved image.
# Processing rock.00085.wav
# Finished processing rock.00085.wav and saved image.
# Processing rock.00078.wav
# Finished processing rock.00078.wav and saved image.
# Processing rock.00019.wav
# Finished processing rock.00019.wav and saved image.
# Processing rock.00082.wav
# Finished processing rock.00082.wav and saved image.
# Processing rock.00022.wav
# Finished processing rock.00022.wav and saved image.
# Processing rock.00090.wav
# Finished processing rock.00090.wav and saved image.
# Processing rock.00009.wav
# Finished processing rock.00009.wav and saved image.
# Processing rock.00067.wav
# Finished processing rock.00067.wav and saved image.
# Processing rock.00086.wav
# Finished processing rock.00086.wav and saved image.
# Processing rock.00000.wav
# Finished processing rock.00000.wav and saved image.
# Processing rock.00079.wav
# Finished processing rock.00079.wav and saved image.
# Processing rock.00087.wav
# Finished processing rock.00087.wav and saved image.
# Processing rock.00018.wav
# Finished processing rock.00018.wav and saved image.
# Processing rock.00059.wav
# Finished processing rock.00059.wav and saved image.
# Processing rock.00020.wav
# Finished processing rock.00020.wav and saved image.
# Processing rock.00095.wav
# Finished processing rock.00095.wav and saved image.
# Processing rock.00010.wav
# Finished processing rock.00010.wav and saved image.
# Processing rock.00092.wav
# Finished processing rock.00092.wav and saved image.
# Processing rock.00021.wav
# Finished processing rock.00021.wav and saved image.
# Processing rock.00093.wav
# Finished processing rock.00093.wav and saved image.
# Processing rock.00074.wav
# Finished processing rock.00074.wav and saved image.
# Processing rock.00063.wav
# Finished processing rock.00063.wav and saved image.
# Processing rock.00036.wav
# Finished processing rock.00036.wav and saved image.
# Processing rock.00027.wav
# Finished processing rock.00027.wav and saved image.
# Processing rock.00007.wav
# Finished processing rock.00007.wav and saved image.
# Processing rock.00034.wav
# Finished processing rock.00034.wav and saved image.
# Processing rock.00071.wav
# Finished processing rock.00071.wav and saved image.
# Processing rock.00088.wav
# Finished processing rock.00088.wav and saved image.
# Processing rock.00008.wav
# Finished processing rock.00008.wav and saved image.
# Processing rock.00084.wav
# Finished processing rock.00084.wav and saved image.
# Processing rock.00083.wav
# Finished processing rock.00083.wav and saved image.
# Processing rock.00070.wav
# Finished processing rock.00070.wav and saved image.
# Processing rock.00058.wav
# Finished processing rock.00058.wav and saved image.
# Processing rock.00032.wav
# Finished processing rock.00032.wav and saved image.
# Processing rock.00091.wav
# Finished processing rock.00091.wav and saved image.
# Processing rock.00060.wav
# Finished processing rock.00060.wav and saved image.
# Processing rock.00011.wav
# Finished processing rock.00011.wav and saved image.
